# %%
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
import numpy as np

# %%
train_df =pd.read_csv("data/train.csv", parse_dates=['timestamp'])
train_df.shape
# Out:
# (30471, 292)

# %%
train_price_df =train_df.price_doc

# %%
train_price_df.shape[0]
# Out:
# 30471

# %%
train_price_df.sort_values(ascending=True).values
# Out:
# array([   100000,    190000,    200000, ...,  91066096,  95122496,
#        111111112], dtype=int64)

# %%
plt.figure(figsize=(10, 10))
plt.scatter(range(train_price_df.shape[0]), train_price_df.sort_values(ascending=True).values)
plt.show()
